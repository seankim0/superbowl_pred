# %% [markdown]
# # Predict Super Bowl Winner
# This program attempts to create a model that can predict the winner of a Super Bowl game using machine learning algorithms.

# %%
import pandas as pd
from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score

# %% [markdown]
# ### Load the data

# %%
df = pd.read_excel('NFL Superbowl Data v2.xlsx')

# %%
df.head(5)
# Out:
#    Season  Year     Super Bowl Team 1     Super Bowl Team 2  \
# 0    1999  2000        St. Louis Rams      Tennessee Titans
# 1    2000  2001      Baltimore Ravens       New York Giants
# 2    2001  2002  New England Patriots        St. Louis Rams
# 3    2002  2003       Oakland Raiders  Tampa Bay Buccaneers
# 4    2003  2004  New England Patriots     Carolina Panthers
#
#                      Result Point Differential (Super Bowl)  \
# 0        St. Louis Rams (W)                               7
# 1      Baltimore Ravens (W)                              27
# 2  New England Patriots (W)                               3
# 3  Tampa Bay Buccaneers (W)                              27
# 4  New England Patriots (W)                               3
#
#    Point Differential (Team1 - Team2)  Super Bowl Team 1 Offense Rank  \
# 0                                 134                               1
# 1                                   5                              14
# 2                                -132                               6
# 3                                 104                               2
# 4                                  23                              12
#
#    Super Bowl Team 2 Offense Rank  Super Bowl Team 1 Defense Rank  \
# 0                               7                               4
# 1                              15                               1
# 2                               1                               6
# 3                              18                               6
# 4                              15                               1
#
#    Super Bowl Team 2 Defense Rank Win - Loss Score  \
# 0                              15            23–16
# 1                               5             34–7
# 2                               7            20–17
# 3                               1            48–21
# 4                              10            32–29
#
#    Super Bowl Team 1 win/loss %  Super Bowl Team 2 win/loss %  \
# 0                         0.813                         0.813
# 1                         0.750                         0.750
# 2                         0.688                         0.875
# 3                         0.688                         0.750
# 4                         0.875                         0.688
#
#    Super Bowl Team 1 Pts Scored  Super Bowl Team 2 Pts Scored  \
# 0                           526                           392
# 1                           333                           328
# 2                           371                           503
# 3                           450                           346
# 4                           348                           325
#
#   Outcome of Team 1
# 0               Win
# 1               Win
# 2               Win
# 3              Lose
# 4               Win

# %%
# convert the team name to integer values
from sklearn.preprocessing import LabelEncoder
le = LabelEncoder()

# create new columns to store the team name integer values
df['Team1'] = le.fit_transform(df['Super Bowl Team 1'])
df['Team2'] = le.fit_transform(df['Super Bowl Team 2'])

df.head(5)
# Out:
#    Season  Year     Super Bowl Team 1     Super Bowl Team 2  \
# 0    1999  2000        St. Louis Rams      Tennessee Titans
# 1    2000  2001      Baltimore Ravens       New York Giants
# 2    2001  2002  New England Patriots        St. Louis Rams
# 3    2002  2003       Oakland Raiders  Tampa Bay Buccaneers
# 4    2003  2004  New England Patriots     Carolina Panthers
#
#                      Result Point Differential (Super Bowl)  \
# 0        St. Louis Rams (W)                               7
# 1      Baltimore Ravens (W)                              27
# 2  New England Patriots (W)                               3
# 3  Tampa Bay Buccaneers (W)                              27
# 4  New England Patriots (W)                               3
#
#    Point Differential (Team1 - Team2)  Super Bowl Team 1 Offense Rank  \
# 0                                 134                               1
# 1                                   5                              14
# 2                                -132                               6
# 3                                 104                               2
# 4                                  23                              12
#
#    Super Bowl Team 2 Offense Rank  Super Bowl Team 1 Defense Rank  \
# 0                               7                               4
# 1                              15                               1
# 2                               1                               6
# 3                              18                               6
# 4                              15                               1
#
#    Super Bowl Team 2 Defense Rank Win - Loss Score  \
# 0                              15            23–16
# 1                               5             34–7
# 2                               7            20–17
# 3                               1            48–21
# 4                              10            32–29
#
#    Super Bowl Team 1 win/loss %  Super Bowl Team 2 win/loss %  \
# 0                         0.813                         0.813
# 1                         0.750                         0.750
# 2                         0.688                         0.875
# 3                         0.688                         0.750
# 4                         0.875                         0.688
#
#    Super Bowl Team 1 Pts Scored  Super Bowl Team 2 Pts Scored  \
# 0                           526                           392
# 1                           333                           328
# 2                           371                           503
# 3                           450                           346
# 4                           348                           325
#
#   Outcome of Team 1  Team1  Team2
# 0               Win     14     16
# 1               Win      1      9
# 2               Win      7     14
# 3              Lose     10     15
# 4               Win      7      1

# %% [markdown]
# ## Remove Last Row to clean up the current Season results
# But in this exercise, we alreay know the 2022 season Super Bowl result. Update the Excel file and add the 2023 season Super Bowl teams.

# %%
df.tail(5)
# Out:
#     Season  Year     Super Bowl Team 1    Super Bowl Team 2  \
# 20    2019  2020    Kansas City Chiefs  San Francisco 49ers
# 21    2020  2021  Tampa Bay Buccaneers   Kansas City Chiefs
# 22    2021  2022      Los Angeles Rams   Cincinnati Bengals
# 23    2022  2023    Kansas City Chiefs  Philadelphia Eagles
# 24    2023  2024    Kansas City Chiefs  San Francisco 49ers
#
#                       Result Point Differential (Super Bowl)  \
# 20    Kansas City Chiefs (W)                              11
# 21  Tampa Bay Buccaneers (W)                              22
# 22      Los Angeles Rams (W)                               3
# 23        Kansas City Chiefs                               3
# 24                         ?                               ?
#
#     Point Differential (Team1 - Team2)  Super Bowl Team 1 Offense Rank  \
# 20                                 -28                               5
# 21                                  19                               3
# 22                                  51                               8
# 23                                  19                               1
# 24                                  73                              15
#
#     Super Bowl Team 2 Offense Rank  Super Bowl Team 1 Defense Rank  \
# 20                               2                               7
# 21                               6                               8
# 22                               7                              15
# 23                               2                              16
# 24                               3                               2
#
#     Super Bowl Team 2 Defense Rank Win - Loss Score  \
# 20                               8            31–20
# 21                              11             31–9
# 22                              17            23–20
# 23                               8            38-35
# 24                               7              ?-?
#
#     Super Bowl Team 1 win/loss %  Super Bowl Team 2 win/loss %  \
# 20                         0.750                         0.813
# 21                         0.688                         0.875
# 22                         0.706                         0.588
# 23                         0.824                         0.824
# 24                         0.824                         0.824
#
#     Super Bowl Team 1 Pts Scored  Super Bowl Team 2 Pts Scored  \
# 20                           451                           479
# 21                           492                           473
# 22                           511                           460
# 23                           496                           477
# 24                           371                           298
#
#    Outcome of Team 1  Team1  Team2
# 20               Win      5     12
# 21               Win     15      6
# 22               Win      6      3
# 23               Win      5     10
# 24                 ?      5     12

# %%
# remove the last row of data from the dataset
data = df.drop(df.tail(1).index)
data.tail(5)
# Out:
#     Season  Year     Super Bowl Team 1    Super Bowl Team 2  \
# 19    2018  2019  New England Patriots     Los Angeles Rams
# 20    2019  2020    Kansas City Chiefs  San Francisco 49ers
# 21    2020  2021  Tampa Bay Buccaneers   Kansas City Chiefs
# 22    2021  2022      Los Angeles Rams   Cincinnati Bengals
# 23    2022  2023    Kansas City Chiefs  Philadelphia Eagles
#
#                       Result Point Differential (Super Bowl)  \
# 19  New England Patriots (W)                              10
# 20    Kansas City Chiefs (W)                              11
# 21  Tampa Bay Buccaneers (W)                              22
# 22      Los Angeles Rams (W)                               3
# 23        Kansas City Chiefs                               3
#
#     Point Differential (Team1 - Team2)  Super Bowl Team 1 Offense Rank  \
# 19                                 -91                               4
# 20                                 -28                               5
# 21                                  19                               3
# 22                                  51                               8
# 23                                  19                               1
#
#     Super Bowl Team 2 Offense Rank  Super Bowl Team 1 Defense Rank  \
# 19                               2                               7
# 20                               2                               7
# 21                               6                               8
# 22                               7                              15
# 23                               2                              16
#
#     Super Bowl Team 2 Defense Rank Win - Loss Score  \
# 19                              20             13–3
# 20                               8            31–20
# 21                              11             31–9
# 22                              17            23–20
# 23                               8            38-35
#
#     Super Bowl Team 1 win/loss %  Super Bowl Team 2 win/loss %  \
# 19                         0.688                         0.813
# 20                         0.750                         0.813
# 21                         0.688                         0.875
# 22                         0.706                         0.588
# 23                         0.824                         0.824
#
#     Super Bowl Team 1 Pts Scored  Super Bowl Team 2 Pts Scored  \
# 19                           436                           527
# 20                           451                           479
# 21                           492                           473
# 22                           511                           460
# 23                           496                           477
#
#    Outcome of Team 1  Team1  Team2
# 19               Win      7      7
# 20               Win      5     12
# 21               Win     15      6
# 22               Win      6      3
# 23               Win      5     10

# %%
# get the relevant features for training the model
features = ['Super Bowl Team 1 Offense Rank', 'Super Bowl Team 2 Offense Rank', 'Super Bowl Team 1 Defense Rank', 'Super Bowl Team 2 Defense Rank', 
           'Super Bowl Team 1 win/loss %', 'Super Bowl Team 2 win/loss %', 'Super Bowl Team 1 Pts Scored', 'Super Bowl Team 2 Pts Scored',
           'Point Differential (Team1 - Team2)', 'Team1', 'Team2']

# %%
# split the data into features and target
X = data[features]
y = data["Outcome of Team 1"]

# %%
# continue splitting the data into 80% training and 20% testing
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.2, random_state=0)

# %%
# train the random forest classifier model on the training dataset
model = RandomForestClassifier(n_estimators=100, random_state=0)
model.fit(X_train, y_train)
# Out:
# RandomForestClassifier(random_state=0)

# %%
# test this model: make predictions on the test data
y_pred = model.predict(X_test)

# %%
# evaluate the model's accuracy
accuracy = accuracy_score(y_test, y_pred)
print('Test Data Accuracy:', accuracy)
# Out:
# Test Data Accuracy: 1.0

# %% [markdown]
# ### Let's Predict the Outcome of the game for year 2024 the Chiefs and the Niners

# %%
last_row = df.tail(1)
last_row
# Out:
#     Season  Year   Super Bowl Team 1    Super Bowl Team 2 Result  \
# 24    2023  2024  Kansas City Chiefs  San Francisco 49ers      ?
#
#    Point Differential (Super Bowl)  Point Differential (Team1 - Team2)  \
# 24                               ?                                  73
#
#     Super Bowl Team 1 Offense Rank  Super Bowl Team 2 Offense Rank  \
# 24                              15                               3
#
#     Super Bowl Team 1 Defense Rank  Super Bowl Team 2 Defense Rank  \
# 24                               2                               7
#
#    Win - Loss Score  Super Bowl Team 1 win/loss %  \
# 24              ?-?                         0.824
#
#     Super Bowl Team 2 win/loss %  Super Bowl Team 1 Pts Scored  \
# 24                         0.824                           371
#
#     Super Bowl Team 2 Pts Scored Outcome of Team 1  Team1  Team2
# 24                           298                 ?      5     12

# %%
# use the trained model to make predictions on this new game
new_game = last_row[features]
prediction = model.predict(new_game)
print(last_row['Super Bowl Team 1'][24]+' are predicted to', prediction[0])
# Out:
# Kansas City Chiefs are predicted to Win
